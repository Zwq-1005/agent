# %%
# !pip install unstructured -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: unstructured in d:\anaconda3\envs\myrag\lib\site-packages (0.18.32)
# Requirement already satisfied: charset-normalizer in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (3.4.7)
# Requirement already satisfied: filetype in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (6.1.1)
# Requirement already satisfied: nltk in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (3.9.4)
# Requirement already satisfied: requests in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (2.34.2)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (4.14.3)
# Requirement already satisfied: emoji in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: dataclasses-json in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (2026.4.20)
# Requirement already satisfied: langdetect in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (2.2.6)
# Requirement already satisfied: rapidfuzz in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (3.14.5)
# Requirement already satisfied: backoff in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (4.15.0)
# Requirement already satisfied: unstructured-client in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (0.42.12)
# Requirement already satisfied: wrapt in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: tqdm in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (4.67.3)
# Requirement already satisfied: psutil in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (7.0.0)
# Requirement already satisfied: python-oxmsg in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: numba in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured) (0.65.1)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\anaconda3\envs\myrag\lib\site-packages (from beautifulsoup4->unstructured) (2.8.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\anaconda3\envs\myrag\lib\site-packages (from dataclasses-json->unstructured) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\anaconda3\envs\myrag\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in d:\anaconda3\envs\myrag\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (26.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\anaconda3\envs\myrag\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in d:\anaconda3\envs\myrag\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in d:\anaconda3\envs\myrag\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in d:\anaconda3\envs\myrag\lib\site-packages (from nltk->unstructured) (8.4.1)
# Requirement already satisfied: joblib in d:\anaconda3\envs\myrag\lib\site-packages (from nltk->unstructured) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\envs\myrag\lib\site-packages (from nltk->unstructured) (2026.5.9)
# Requirement already satisfied: colorama in d:\anaconda3\envs\myrag\lib\site-packages (from click->nltk->unstructured) (0.4.6)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in d:\anaconda3\envs\myrag\lib\site-packages (from numba->unstructured) (0.47.0)
# Requirement already satisfied: olefile in d:\anaconda3\envs\myrag\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\myrag\lib\site-packages (from requests->unstructured) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\anaconda3\envs\myrag\lib\site-packages (from requests->unstructured) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in d:\anaconda3\envs\myrag\lib\site-packages (from requests->unstructured) (2026.5.20)
# Requirement already satisfied: aiofiles>=24.1.0 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured-client->unstructured) (25.1.0)
# Requirement already satisfied: cryptography>=3.1 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured-client->unstructured) (48.0.0)
# Requirement already satisfied: httpcore>=1.0.9 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured-client->unstructured) (2.13.4)
# Requirement already satisfied: pypdf>=6.2.0 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured-client->unstructured) (6.12.1)
# Requirement already satisfied: pypdfium2>=5.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured-client->unstructured) (5.8.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=2.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (2.0.0)
# Requirement already satisfied: pycparser in d:\anaconda3\envs\myrag\lib\site-packages (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->unstructured) (3.0)
# Requirement already satisfied: h11>=0.16 in d:\anaconda3\envs\myrag\lib\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in d:\anaconda3\envs\myrag\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.13.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\anaconda3\envs\myrag\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.0)

# %%
# !pip install docx -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: docx in d:\anaconda3\envs\myrag\lib\site-packages (0.2.4)
# Requirement already satisfied: lxml in d:\anaconda3\envs\myrag\lib\site-packages (from docx) (6.1.1)
# Requirement already satisfied: Pillow>=2.0 in d:\anaconda3\envs\myrag\lib\site-packages (from docx) (12.2.0)

# %%
# !pip install langchain -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting langchain
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f8/82/a54edcd1c48163de5642eb10fa2cb58b13a8889c659964f63f0306b58b1e/langchain-1.3.2-py3-none-any.whl (121 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain) (1.4.0)
# Collecting langgraph<1.3.0,>=1.2.2 (from langchain)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/42/9b/b08d578bba73e25351152dfd3d6d21e81210a5fff1b6f26e56f33197c8f5/langgraph-1.2.2-py3-none-any.whl (236 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda3\envs\myrag\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.1.1)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.2->langchain)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/bd/b4/71425e3e38be92611300b9cc5e46a5bf98ab23f5ea8a75b73d02a2f1413c/langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.2->langchain)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e9/43/3fe1a700b8490ed02679cdbbc8c915eb23a092faf496c9c1118abcd10be3/langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.3.0,>=1.2.2->langchain)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/be/a5/0196d9c05749c25bc198e4909d68c998bc3120297e14944921baf2f4c384/langgraph_sdk-0.3.15-py3-none-any.whl (98 kB)
# Requirement already satisfied: xxhash>=3.5.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (3.7.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.2->langchain)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/8d/a2/e6532ed7716aed03dede8df2d0d0d4150710c2122647d94b474147ccd891/ormsgpack-1.12.2-cp310-cp310-win_amd64.whl (117 kB)
# Requirement already satisfied: httpx>=0.25.2 in d:\anaconda3\envs\myrag\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\anaconda3\envs\myrag\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\anaconda3\envs\myrag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (4.13.0)
# Requirement already satisfied: certifi in d:\anaconda3\envs\myrag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in d:\anaconda3\envs\myrag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda3\envs\myrag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (3.16)
# Requirement already satisfied: h11>=0.16 in d:\anaconda3\envs\myrag\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda3\envs\myrag\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\anaconda3\envs\myrag\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\anaconda3\envs\myrag\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (1.3.0)
# Installing collected packages: ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ------ --------------------------------- 1/6 [langgraph-sdk]
#    ------ --------------------------------- 1/6 [langgraph-sdk]
#    ------ --------------------------------- 1/6 [langgraph-sdk]
#    ------ --------------------------------- 1/6 [langgraph-sdk]
#    ------ --------------------------------- 1/6 [langgraph-sdk]
#    ------ --------------------------------- 1/6 [langgraph-sdk]
#    ------------- -------------------------- 2/6 [langgraph-checkpoint]
#    ------------- -------------------------- 2/6 [langgraph-checkpoint]
#    ------------- -------------------------- 2/6 [langgraph-checkpoint]
#    ------------- -------------------------- 2/6 [langgraph-checkpoint]
#    -------------------- ------------------- 3/6 [langgraph-prebuilt]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    -------------------------- ------------- 4/6 [langgraph]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    ---------------------------------------- 6/6 [langchain]
#
# Successfully installed langchain-1.3.2 langgraph-1.2.2 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.3.15 ormsgpack-1.12.2

# %%
# !pip install langchain_openai -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: langchain_openai in d:\anaconda3\envs\myrag\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain_openai) (1.4.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain_openai) (2.38.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain_openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda3\envs\myrag\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_openai) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (2.34.2)
# Requirement already satisfied: xxhash>=3.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda3\envs\myrag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (0.25.0)
# Requirement already satisfied: anyio in d:\anaconda3\envs\myrag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (4.13.0)
# Requirement already satisfied: certifi in d:\anaconda3\envs\myrag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in d:\anaconda3\envs\myrag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda3\envs\myrag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (3.16)
# Requirement already satisfied: h11>=0.16 in d:\anaconda3\envs\myrag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anaconda3\envs\myrag\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\anaconda3\envs\myrag\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.15.0)
# Requirement already satisfied: sniffio in d:\anaconda3\envs\myrag\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\anaconda3\envs\myrag\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.67.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\anaconda3\envs\myrag\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.0->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.0->langchain_openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda3\envs\myrag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.0->langchain_openai) (0.4.2)
# Requirement already satisfied: regex in d:\anaconda3\envs\myrag\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.5.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda3\envs\myrag\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\anaconda3\envs\myrag\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_openai) (2.7.0)
# Requirement already satisfied: colorama in d:\anaconda3\envs\myrag\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain_openai) (0.4.6)

# %%
# !pip install streamlit -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: streamlit in d:\anaconda3\envs\myrag\lib\site-packages (1.57.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging>=20 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (7.35.0)
# Requirement already satisfied: pyarrow>=7.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (1.1.0)
# Requirement already satisfied: uvicorn>=0.30.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (0.48.0)
# Requirement already satisfied: httptools>=0.6.3 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (0.0.29)
# Requirement already satisfied: websockets>=12.0.0 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in d:\anaconda3\envs\myrag\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in d:\anaconda3\envs\myrag\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in d:\anaconda3\envs\myrag\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in d:\anaconda3\envs\myrag\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.21.2)
# Requirement already satisfied: colorama in d:\anaconda3\envs\myrag\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\anaconda3\envs\myrag\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\anaconda3\envs\myrag\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda3\envs\myrag\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\myrag\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\envs\myrag\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda3\envs\myrag\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\myrag\lib\site-packages (from requests<3,>=2.27->streamlit) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\anaconda3\envs\myrag\lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in d:\anaconda3\envs\myrag\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.5.20)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\anaconda3\envs\myrag\lib\site-packages (from anyio>=4.0.0->streamlit) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\envs\myrag\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda3\envs\myrag\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3\envs\myrag\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3\envs\myrag\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\anaconda3\envs\myrag\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\myrag\lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in d:\anaconda3\envs\myrag\lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
