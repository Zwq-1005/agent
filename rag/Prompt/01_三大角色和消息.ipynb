# %%
from langchain.messages import SystemMessage
from langchain.messages import HumanMessage
from langchain.messages import AIMessage

# %%
#写法一
message1 = [
    SystemMessage(content="你是一个语言翻译专家，请把用户输入的内容翻译成英语"),
    HumanMessage(content="汤姆和杰瑞是一对好朋友！")
]

# %%
#写法二
message2 = [
    ("system","你是一个语言翻译专家，请把用户输入的内容翻译成英语"),
    ("user","汤姆和杰瑞是一对好朋友！")
]

# %%
#写法三
message3 = [
    {
        "role":"system",
        "content":"你是一个语言翻译专家，请把用户输入的内容翻译成英语"
    },
    {
        "role":"user",
        "content":"汤姆和杰瑞是一对好朋友！"
    }
]
